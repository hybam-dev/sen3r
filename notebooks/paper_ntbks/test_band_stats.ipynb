# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path

# %%
df_b3c = pd.read_csv(Path(r'D:/A1_JM/artigo_SEN3R/3_results/test_band_combinations/band_3_comb_stats.csv'))

# %%
df_b3c
# Out:
#         station                             cluster_bands  itr_pcorr  \
# 0    manacapuru            ['B4-490', 'B6-560', 'B8-665']   0.580306
# 1    manacapuru           ['B4-490', 'B6-560', 'B17-865']   0.578193
# 2    manacapuru          ['B4-490', 'B6-560', 'B21-1020']   0.614308
# 3    manacapuru        ['B4-490', 'B6-560', 'T865:float']   0.587795
# 4    manacapuru        ['B4-490', 'B6-560', 'A865:float']   0.518540
# ..          ...                                       ...        ...
# 100      obidos    ['B8-665', 'T865:float', 'A865:float']   0.617174
# 101      obidos     ['B17-865', 'B21-1020', 'T865:float']   0.661745
# 102      obidos     ['B17-865', 'B21-1020', 'A865:float']   0.604240
# 103      obidos   ['B17-865', 'T865:float', 'A865:float']   0.601371
# 104      obidos  ['B21-1020', 'T865:float', 'A865:float']   0.635896
#
#      itr_scorr  itr_rmse_log   itr_rmse   itr_mape  itr_pbias    itr_r2  \
# ...

# %%
plt.boxplot(df_b3c['itr_rmse_log'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22f814667f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22f81466da0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22f81466588>],
#  'medians': [<matplotlib.lines.Line2D at 0x22f81474390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22f81474668>],
#  'means': []}

# %%
df_stats_sorted = df_b3c.sort_values(by=['itr_rmse_log'], ascending=False)
df_stats_sorted.reset_index(inplace=True)

# %%
df_stats_sorted
# Out:
#      index        station                           cluster_bands  itr_pcorr  \
# 0       58  borba_madeira    ['B6-560', 'B21-1020', 'A865:float']   0.530589
# 1       56  borba_madeira     ['B6-560', 'B17-865', 'A865:float']   0.564094
# 2       46  borba_madeira     ['B4-490', 'B17-865', 'A865:float']   0.547664
# 3       43  borba_madeira      ['B4-490', 'B8-665', 'A865:float']   0.581571
# 4       53  borba_madeira      ['B6-560', 'B8-665', 'A865:float']   0.588543
# ..     ...            ...                                     ...        ...
# 100     30     manacapuru  ['B8-665', 'T865:float', 'A865:float']   0.597878
# 101     32     manacapuru   ['B17-865', 'B21-1020', 'A865:float']   0.581120
# 102     13     manacapuru    ['B4-490', 'B21-1020', 'A865:float']   0.580143
# 103     23     manacapuru    ['B6-560', 'B21-1020', 'A865:float']   0.589167
# 104     11     manacapuru     ['B4-490', 'B17-865', 'A865:float']   0.586758
#
# ...

# %%
plt.plot(df_stats_sorted['itr_rmse_log'])
